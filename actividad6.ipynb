# %% [markdown]
# Carga un archivo CSV llamado housing.csv en una variable para poder trabajar y analizar sus datos con pandas

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
import pandas as pd

datos = pd.read_csv('housing.csv')

# %% [markdown]
# Muestra las primeras filas del dataset para ver cómo están organizados los datos

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Cuenta cuántas veces aparece cada categoría en la columna ocean_proximity

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %% [markdown]
# Muestra un resumen del dataset incluyendo columnas tipos de datos valores no nulos y uso de memoria

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Genera estadísticas básicas del dataset como promedio mínimo máximo y desviación estándar

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Genera histogramas de las variables numéricas para visualizar la distribución de los datos

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos.hist(figsize=(15, 8), bins = 30, edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# Crea un gráfico de dispersión filtrando datos con ingresos altos mostrando la relación entre ubicación y valor de casas con colores según su precio

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
import seaborn as sb
sb.scatterplot(x="latitude", y="longitude", data=datos, hue="median_house_value", palette="coolwarm",
s=datos["population"]/100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 import seaborn as sb
# ----> 2 sb.scatterplot(x="latitude", y="longitude", data=datos, hue="median_house_value", palette="coolwarm",
#       3 s=datos["population"]/100)
#
# File c:\Users\lemus\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File c:\Users\lemus\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:464, in _ScatterPlotter.plot(self, ax, kws)
#     462 if self.legend:
# ...

# %% [markdown]
# Muestra un resumen del dataset incluyendo columnas tipos de datos valores no nulos y uso de memoria

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Elimina las filas con valores faltantes del dataset y guarda el resultado en una nueva variable

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos_na = datos.dropna()

# %% [markdown]
# Muestra un resumen del nuevo dataset sin valores faltantes incluyendo columnas tipos de datos y cantidad de registros

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# Accede a la columna ocean_proximity del dataset para visualizar sus valores categóricos

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
#convertir la caracteristica categorica a numerica
#Proximidad al oceano
datos_na['ocean_proximity']
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20433, dtype: object

# %% [markdown]
# Cuenta la frecuencia de cada categoría en la columna ocean_proximity para ver cuántos valores hay de cada tipo

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos_na['ocean_proximity'].value_counts()
#1,2,3,4,5
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %% [markdown]
# Convierte la columna categórica ocean_proximity en variables numéricas binarias usando one hot encoding

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
#Dumies / One-Hot Encoding
# NEAR BAY  INLAND  NEAR OCEAN
#   1          0         0
#   0          1         0

dummies = pd.get_dummies(datos_na["ocean_proximity"], dtype=int)

# %% [markdown]
# Agrega al dataset las nuevas columnas generadas por el one hot encoding

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos_na = datos_na.join(dummies)

# %% [markdown]
# Muestra las primeras filas del dataset actualizado con las nuevas columnas añadidas

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos_na.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %% [markdown]
# Elimina la columna ocean_proximity del dataset para dejar solo variables numéricas

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos_na = datos_na.drop(["ocean_proximity"], axis=1)

# %% [markdown]
# Muestra las primeras filas del dataset actualizado después de eliminar la columna categórica

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
datos_na.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  <1H OCEAN  \
# 0       322.0       126.0         8.3252            452600.0          0
# 1      2401.0      1138.0         8.3014            358500.0          0
# 2       496.0       177.0         7.2574            352100.0          0
# 3       558.0       219.0         5.6431            341300.0          0
# 4       565.0       259.0         3.8462            342200.0          0
#
#    INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       0       0         1           0
# ...

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
#Analisis, nuevas caracteristicas

# %% [markdown]
# Genera un mapa de calor que muestra la correlación entre las variables del dataset

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.

# %%
sb.set(rc={'figure.figsize':(15, 8)})
sb.heatmap(datos_na.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque realiza operaciones relacionadas con el análisis o procesamiento de datos. Se encarga de ejecutar instrucciones que permiten manipular, transformar o visualizar información.
# Revisa las variables utilizadas para entender cómo fluye la información dentro del bloque.
