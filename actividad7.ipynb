# %% [markdown]
# Carga un archivo CSV llamado housing.csv en una variable para poder trabajar y analizar sus datos con pandas

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
import pandas as pd

datos = pd.read_csv('housing.csv')

# %% [markdown]
# Muestra las primeras filas del dataset para ver cómo están organizados los datos

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Cuenta cuántas veces aparece cada categoría en la columna ocean_proximity

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %% [markdown]
# Muestra un resumen del dataset incluyendo columnas tipos de datos valores no nulos y uso de memoria

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Genera estadísticas básicas del dataset como promedio mínimo máximo y desviación estándar

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Genera histogramas de las variables numéricas para visualizar la distribución de los datos

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos.hist(figsize=(15, 8), bins = 30, edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# Crea un gráfico de dispersión filtrando datos con ingresos altos mostrando la relación entre ubicación y valor de casas con colores según su precio

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
import seaborn as sb
sb.scatterplot(x='longitude', y='latitude', data=datos[(datos.median_income > 14)], hue='median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# Muestra un resumen del dataset incluyendo columnas tipos de datos valores no nulos y uso de memoria

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Elimina las filas con valores faltantes del dataset y guarda el resultado en una nueva variable

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na = datos.dropna()

# %% [markdown]
# Muestra un resumen del nuevo dataset sin valores faltantes incluyendo columnas tipos de datos y cantidad de registros

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# Accede a la columna ocean_proximity del dataset para visualizar sus valores categóricos

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
#convertir la caracteristica categorica a numerica
#Proximidad al oceano
datos_na['ocean_proximity']
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20433, dtype: object

# %% [markdown]
# Cuenta la frecuencia de cada categoría en la columna ocean_proximity para ver cuántos valores hay de cada tipo

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na['ocean_proximity'].value_counts()
#1,2,3,4,5
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %% [markdown]
# Convierte la columna categórica ocean_proximity en variables numéricas binarias usando one hot encoding

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
#Dumies / One-Hot Encoding
# NEAR BAY  INLAND  NEAR OCEAN
#   1          0         0
#   0          1         0

dummies = pd.get_dummies(datos_na["ocean_proximity"], dtype=int)

# %% [markdown]
# Agrega al dataset las nuevas columnas generadas por el one hot encoding

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na = datos_na.join(dummies)

# %% [markdown]
# Muestra las primeras filas del dataset actualizado con las nuevas columnas añadidas

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %% [markdown]
# Elimina la columna ocean_proximity del dataset para dejar solo variables numéricas

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na = datos_na.drop(["ocean_proximity"], axis=1)

# %% [markdown]
# Muestra las primeras filas del dataset actualizado después de eliminar la columna categórica

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  <1H OCEAN  \
# 0       322.0       126.0         8.3252            452600.0          0
# 1      2401.0      1138.0         8.3014            358500.0          0
# 2       496.0       177.0         7.2574            352100.0          0
# 3       558.0       219.0         5.6431            341300.0          0
# 4       565.0       259.0         3.8462            342200.0          0
#
#    INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       0       0         1           0
# ...

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
#Analisis, nuevas caracteristicas

# %% [markdown]
# Genera un mapa de calor que muestra la correlación entre las variables del dataset

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
sb.set(rc={'figure.figsize':(15, 8)})
sb.heatmap(datos_na.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na.corr()["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688355
# <1H OCEAN             0.257614
# NEAR BAY              0.160526
# NEAR OCEAN            0.140378
# total_rooms           0.133294
# housing_median_age    0.106432
# households            0.064894
# total_bedrooms        0.049686
# ISLAND                0.023525
# population           -0.025300
# longitude            -0.045398
# latitude             -0.144638
# INLAND               -0.484787
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
sb.scatterplot(x=datos_na["median_house_value"], y=datos_na["median_income"])
# Out:
# <Axes: xlabel='median_house_value', ylabel='median_income'>

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na["bedroom_ratio"] = datos_na["total_bedrooms"] / datos_na["total_rooms"]

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
sb.set(rc={'figure.figsize':(15, 8)})
sb.heatmap(datos_na.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# Separa las variables predictoras en X y la variable objetivo median_house_value en y

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
#separar las carateristicas de la etiqueta
X = datos_na.drop("median_house_value", axis=1)
y = datos_na["median_house_value"]

# %% [markdown]
# Divide los datos en conjuntos de entrenamiento y prueba para poder entrenar y evaluar el modelo

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
#separar los datos en 2 partes: cConjunto de entrenamiento y uno de pruebas
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X,y, test_size=.2)

# %% [markdown]
# Importa el modelo de regresión lineal y crea una instancia lista para entrenarse

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

# %% [markdown]
# Entrena el modelo usando los datos de entrenamiento para aprender la relación entre variables

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
modelo.fit(X_ent, y_ent)
# Out:
# LinearRegression()

# %% [markdown]
# Genera predicciones usando el modelo entrenado sobre los datos de prueba

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
predicciones = modelo.predict(X_pru)

# %% [markdown]
# Crea una tabla que compara las predicciones del modelo con los valores reales

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
comparativa = {"Prediccion": predicciones, "Valor Real": y_pru}
pd.DataFrame(comparativa)
# Out:
#           Prediccion  Valor Real
# 6959   220157.741028    167300.0
# 12471  113280.413918    109800.0
# 1122    44280.527309    104900.0
# 17224  262437.268046    289900.0
# 1376   240867.718398    172400.0
# ...              ...         ...
# 5806   154185.624686    248100.0
# 4270   198735.868204    237500.0
# 13561  249625.753339    159700.0
# 15544  233044.761877    353000.0
# 2210   118307.774576     88800.0
#
# [4087 rows x 2 columns]

# %% [markdown]
# Calcula y muestra el rendimiento del modelo en entrenamiento y prueba para detectar posible sobreajuste

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
#Overfitting sobreajuste
print(modelo.score(X_ent, y_ent))
print(modelo.score(X_pru, y_pru))
# Out:
# 0.6533750924212534
# 0.6449896953054047

# %% [markdown]
# Calcula el error cuadrático medio entre los valores reales y las predicciones del modelo

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
#Error
from sklearn.metrics import mean_squared_error
import numpy as np

mse=mean_squared_error(y_pru, predicciones)

# %% [markdown]
# Muestra el valor del error cuadrático medio calculado

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
mse
# Out:
# 4650398684.48146

# %% [markdown]
# Calcula la raíz del error cuadrático medio para obtener una medida del error en la misma escala de los datos

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
rmse = np.sqrt(mse)

# %% [markdown]
# Muestra el valor de la raíz del error cuadrático medio calculado

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
rmse
# Out:
# np.float64(68193.83171872262)

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
#Scaler escalamiento

# %% [markdown]
# Genera estadísticas básicas del dataset limpio como promedio mínimo máximo y desviación estándar

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
datos_na.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Estandariza los datos de entrenamiento y prueba para que todas las variables tengan la misma escala

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_ent_esc = scaler.fit_transform(X_ent)
X_pru_esc = scaler.transform(X_pru)

# %% [markdown]
# Muestra los datos de entrenamiento originales sin escalar

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
X_ent
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20162    -119.34     34.39                27.0        669.0           131.0
# 3199     -119.65     36.35                21.0       1745.0           266.0
# 11772    -121.30     38.75                36.0       3903.0           885.0
# 6891     -118.10     34.05                26.0       1495.0           328.0
# 16207    -121.31     37.94                41.0        375.0           108.0
# ...          ...       ...                 ...          ...             ...
# 15260    -117.27     33.03                16.0       2240.0           443.0
# 12763    -121.40     38.62                28.0       3671.0           886.0
# 11960    -117.43     33.91                15.0      14281.0          2511.0
# 3288     -122.73     39.04                23.0       1618.0           395.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
#
# ...

# %% [markdown]
# Convierte los datos de entrenamiento escalados en un DataFrame para poder visualizarlos mejor

# %% [markdown]
# ### Explicación del bloque de código
#
# Este bloque ejecuta una serie de instrucciones para procesar datos, aplicar transformaciones o generar resultados. Es importante observar las variables de entrada y salida para entender cómo contribuye al flujo general del análisis.
# Cada línea cumple una función específica dentro del proceso, ya sea cálculo, limpieza o visualización.

# %%
pd.DataFrame(X_ent_esc)
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.119112 -0.586702 -0.130972 -0.897044 -0.967376 -1.000782 -1.033688
# 1     -0.035585  0.329950 -0.606880 -0.403868 -0.644367 -0.525639 -0.541549
# 2     -0.858976  1.452381  0.582889  0.585233  0.836691  0.815298  0.813153
# 3      0.737903 -0.745713 -0.210290 -0.518453 -0.496022 -0.108640 -0.509799
# 4     -0.863966  1.073561  0.979479 -1.031796 -1.022407 -0.992605 -1.054855
# ...         ...       ...       ...       ...       ...       ...       ...
# 16341  1.152093 -1.222747 -1.003469 -0.176989 -0.220865 -0.283071 -0.213457
# 16342 -0.908878  1.391583 -0.051654  0.478898  0.839084  0.288372  0.855488
# 16343  1.072249 -0.811189 -1.082787  5.341902  4.727161  5.563997  4.625901
# 16344 -1.572581  1.588009 -0.448244 -0.462077 -0.335713 -0.899939 -0.668553
# 16345 -0.868956  1.770404 -0.844833 -0.351159 -0.302216 -0.612855 -0.390733
#
# ...
